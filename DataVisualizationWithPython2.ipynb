# %% [markdown]
# ># **Data Visualization with Python (Part 2)**

# %% [markdown]
# - In this notebook I will plot maps with Markers.
#
# - My dataset contains the data on police department incidents and its format is .csv. I've uploaded the dataset to Google Drive.
#
# *Let's get started!*

# %%
# !pip install -q -U watermark

# %%
# %reload_ext watermark
# %watermark -v -p numpy,pandas,matplotlib
# Out:
# Python implementation: CPython
# Python version       : 3.7.14
# IPython version      : 7.9.0
#
# numpy     : 1.21.6
# pandas    : 1.3.5
# matplotlib: 3.2.2

# %%
#import os
import numpy as np
import pandas as pd
#from tqdm import tqdm
#import seaborn as sns
#from pylab import rcParams
# %matplotlib inline 
import matplotlib as mpl
import matplotlib.pyplot as plt
#from matplotlib import rc
#from scipy import stats

#import matplotlib.patches as mpatches
#from PIL import Image

import folium

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !ls '/content/gdrive'
# Out:
# MyDrive

# %%
df = pd.read_csv('/content/gdrive/MyDrive/PoliceDepartmentIncidents.csv',encoding = "ISO-8859-1")
df.head(2)
# Out:
#    IncidntNum     Category                                        Descript  \
# 0   120058272  WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1   120058272  WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
#
#   DayOfWeek            Date   Time PdDistrict      Resolution  \
# 0    Friday  1/29/2016 0:00  11:00   SOUTHERN  ARREST, BOOKED
# 1    Friday  1/29/2016 0:00  11:00   SOUTHERN  ARREST, BOOKED
#
#                   Address           X          Y  \
# 0  800 Block of BRYANT ST -122.403405  37.775421
# 1  800 Block of BRYANT ST -122.403405  37.775421
#
#                                Location          PdId
# 0  (37.775420706711, -122.403404791479)  1.200000e+13
# 1  (37.775420706711, -122.403404791479)  1.200000e+13

# %% [markdown]
# >***Just a Note***
# - **IncidntNum:** Incident Number
# - **Category:** Category of crime or incident
# - **Descript:** Description of the crime or incident
# - **DayOfWeek:** The day of week on which the incident occurred
# - **Date:** The Date on which the incident occurred
# - **Time:** The time of day on which the incident occurred
# - **PdDistrict:** The police department district
# - **Resolution:** The resolution of the crime in terms whether the perpetrator was arrested or not
# - **Address:** The closest address to where the incident took place
# - **X:** The longitude value of the crime location
# - **Y:** The latitude value of the crime location
# - **Location:** A tuple of the latitude and the longitude values
# - **PdId:** The police department ID

# %%
#finding out how many entries there are in our dataset.
df.shape
# Out:
# (150500, 13)

# %% [markdown]
# - I will work with the first 200 incidents in this dataset.

# %%
# get the first 200 crimes in the df_incidents dataframe
limit = 200
df = df.iloc[0:limit, :]

df.shape
# Out:
# (200, 13)

# %% [markdown]
# I want to visualize where these crimes took place in the city of San Francisco. I will use the default style, and we will initialize the zoom level to 10.

# %%
# San Francisco latitude and longitude values
latitude = 37.77
longitude = -122.42

# I must create map and display it
SanFrancisco_map = folium.Map(location=[latitude, longitude], zoom_start=10)


SanFrancisco_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0436e6f8a0687b529690c2bcd99df66f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0436e6f8a0687b529690c2bcd99df66f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0436e6f8a0687b529690c2bcd99df66f = L.map(
#                 &quot;map_0436e6f8a0687b529690c2bcd99df66f&quot;,
#                 {
#                     center: [37.77, -122.42],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4b47f260f46dbb805b114324e0b09c97 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0436e6f8a0687b529690c2bcd99df66f);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# - I will superimpose the locations of the crimes onto the map. The way to do that in Folium is to create a feature group with its own features and style and then add it to the Merced_map.

# %%
# instantiate a feature group for the incidents in the dataframe
incidents = folium.map.FeatureGroup()

# loop through the 200 crimes and add each to the incidents feature group
for lat, lng, in zip(df.Y, df.X):
    incidents.add_child(
        folium.features.CircleMarker(
            [lat, lng],
            radius=5, # define how big you want the circle markers to be
            color='pink',
            fill=True,
            fill_color='red',
            fill_opacity=0.6
        )
    )

# add pop-up text to each marker on the map
latitudes = list(df.Y)
longitudes = list(df.X)
labels = list(df.Category)

for lat, lng, label in zip(latitudes, longitudes, labels):
    folium.Marker([lat, lng], popup=label).add_to(SanFrancisco_map)    
    

SanFrancisco_map.add_child(incidents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0436e6f8a0687b529690c2bcd99df66f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0436e6f8a0687b529690c2bcd99df66f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0436e6f8a0687b529690c2bcd99df66f = L.map(
#                 &quot;map_0436e6f8a0687b529690c2bcd99df66f&quot;,
#                 {
#                     center: [37.77, -122.42],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4b47f260f46dbb805b114324e0b09c97 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0436e6f8a0687b529690c2bcd99df66f);
#
#
#             var marker_83d4d071d49211a4909dd171afc5ad29 = L.marker(
#                 [37.77542071, -122.4034048],
#                 {}
#             ).addTo(map_0436e6f8a0687b529690c2bcd99df66f);
#
#
#         var popup_60795fec7ced511182ec84df6a400faa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4b38954ffa6d1b6ea72dd7bf35c4ddb7 = $(`&lt;div id=&quot;html_4b38954ffa6d1b6ea72dd7bf35c4ddb7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;`)[0];
#             popup_60795fec7ced511182ec84df6a400faa.setContent(html_4b38954ffa6d1b6ea72dd7bf35c4ddb7);
#
#
#         marker_83d4d071d49211a4909dd171afc5ad29.bindPopup(popup_60795fec7ced511182ec84df6a400faa)
#         ;
#
#
#
#
#             var marker_991daf6e810003d2c4e36b7afa2d8e8f = L.marker(
#                 [37.77542071, -122.4034048],
#                 {}
#             ).addTo(map_0436e6f8a0687b529690c2bcd99df66f);
#
#
#         var popup_88af04ce3fd347a810c917ddfd04a9f7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b008ac89e35c1f55aaafe1c127386da9 = $(`&lt;div id=&quot;html_b008ac89e35c1f55aaafe1c127386da9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;`)[0];
#             popup_88af04ce3fd347a810c917ddfd04a9f7.setContent(html_b008ac89e35c1f55aaafe1c127386da9);
#
#
#         marker_991daf6e810003d2c4e36b7afa2d8e8f.bindPopup(popup_88af04ce3fd347a810c917ddfd04a9f7)
#         ;
#
#
#
#
#             var marker_5a9bf9d10930940c99c0ec97640ddafa = L.marker(
#                 [37.72998097, -122.3888562],
#                 {}
#             ).addTo(map_0436e6f8a0687b529690c2bcd99df66f);
#
#
#         var popup_c955cb86829c7eb3200f28ccf47a3718 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_483594a202ed0f6d697eb5a4209fdfc0 = $(`&lt;div id=&quot;html_483594a202ed0f6d697eb5a4209fdfc0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WARRANTS&lt;/div&gt;`)[0];
#             popup_c955cb86829c7eb3200f28ccf47a3718.setContent(html_483594a202ed0f6d697eb5a4209fdfc0);
#
#
#         marker_5a9bf9d10930940c99c0ec97640ddafa.bindPopup(popup_c955cb86829c7eb3200f28ccf47a3718)
#         ;
#
#
#
#
#             var marker_cd121ed650816f53c67c64f5f670aaed = L.marker(
#                 [37.78578838, -122.4129705],
#                 {}
#             ).addTo(map_0436e6f8a0687b529690c2bcd99df66f);
#
#
#         var popup_cbe4faf7e17d187fcd61ffecd6cd4f3f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5d0628a765f5f3cab278c3fb21ce833b = $(`&lt;div id=&quot;html_5d0628a765f5f3cab278c3fb21ce833b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NON-CRIMINAL&lt;/div&gt;`)[0];
#             popup_cbe4faf7e17d187fcd61ffecd6cd4f3f.setContent(html_5d0628a765f5f3cab278c3fb21ce833b);
#
#
#         marker_cd121ed650816f53c67c64f5f670aaed.bindPopup(popup_cbe4faf7e17d187fcd61ffecd6cd4f3f)
#         ;
#
#
#
#
#             var marker_68b806154f952f6cd98af77aac26b0f8 = L.marker(
#                 [37.76505012, -122.4196718],
#                 {}
#             ).addTo(map_0436e6f8a0687b529690c2bcd99df66f);
#
#
#         var popup_fea23de181f476243911a5c2ad733d25 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3df219c5bfd4cb898293108931ae2b8f = $(`&lt;div id=&quot;html_3df219c5bfd4cb898293108931ae2b8f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NON-CRIMINAL&lt;/div&gt;`)[0];
#             popup_fea23de181f476243911a5c2ad733d25.setContent(html_3df219c5bfd4cb898293108931ae2b8f);
#
#
#         marker_68b806154f952f6cd98af77aac26b0f8.bindPopup(popup_fea23de181f476243911a5c2ad733d25)
#         ;
#
#
#
#
#             var marker_f71601f56cf5b9aebd4d6b46b13fbe7c = L.marker(
#                 [37.78801856, -122.4260772],
#                 {}
#             ).addTo(map_0436e6f8a0687b529690c2bcd99df66f);
#
#
#         var popup_2872cce50265378048691e6b92e2f95e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_8da7b9b634d8bad00a508a0766cee7f8 = $(`&lt;div id=&quot;html_8da7b9b634d8bad00a508a07

# %% [markdown]
# - Now, I am able to know what crime category occurred at each marker.

# %% [markdown]
# - I will remove these location markers and just add the text to the circle markers themselves.  It helps me to figure out the main features better.

# %%
# I will create map and display it
SanFrancisco_map = folium.Map(location=[latitude, longitude], zoom_start=10)


for lat, lng, label in zip(df.Y, df.X, df.Category):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5, # define how big I want the circle markers to be
        color='pink',
        fill=True,
        popup=label,
        fill_color='red',
        fill_opacity=0.6
    ).add_to(SanFrancisco_map)

SanFrancisco_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d1cd1f011d4943df63d1f58f3c274d2e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d1cd1f011d4943df63d1f58f3c274d2e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_d1cd1f011d4943df63d1f58f3c274d2e = L.map(
#                 &quot;map_d1cd1f011d4943df63d1f58f3c274d2e&quot;,
#                 {
#                     center: [37.77, -122.42],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_097b0e07a9eeee73c6910ef2701ba703 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d1cd1f011d4943df63d1f58f3c274d2e);
#
#
#             var circle_marker_99ac6f5e1e54289d0388ddcb93986be8 = L.circleMarker(
#                 [37.77542071, -122.4034048],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;pink&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d1cd1f011d4943df63d1f58f3c274d2e);
#
#
#         var popup_2610da6728a33e717980a4200eca6dbd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_676353046bfd6c81570c5c6b5cedeb46 = $(`&lt;div id=&quot;html_676353046bfd6c81570c5c6b5cedeb46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;`)[0];
#             popup_2610da6728a33e717980a4200eca6dbd.setContent(html_676353046bfd6c81570c5c6b5cedeb46);
#
#
#         circle_marker_99ac6f5e1e54289d0388ddcb93986be8.bindPopup(popup_2610da6728a33e717980a4200eca6dbd)
#         ;
#
#
#
#
#             var circle_marker_02244283615e745ad9119648d9c5f2f1 = L.circleMarker(
#                 [37.77542071, -122.4034048],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;pink&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d1cd1f011d4943df63d1f58f3c274d2e);
#
#
#         var popup_740f5bb26b2dd86f9e6f6b857a8401cc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1f5b0cd9a30eb6b9a638b6006d446def = $(`&lt;div id=&quot;html_1f5b0cd9a30eb6b9a638b6006d446def&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;`)[0];
#             popup_740f5bb26b2dd86f9e6f6b857a8401cc.setContent(html_1f5b0cd9a30eb6b9a638b6006d446def);
#
#
#         circle_marker_02244283615e745ad9119648d9c5f2f1.bindPopup(popup_740f5bb26b2dd86f9e6f6b857a8401cc)
#         ;
#
#
#
#
#             var circle_marker_b7cde353c5ac4f62bc0c32e97d84b07c = L.circleMarker(
#                 [37.72998097, -122.3888562],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;pink&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d1cd1f011d4943df63d1f58f3c274d2e);
#
#
#         var popup_e47010b528de57876ce302e3877f55e3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_0c08f955e59c885919f1f5a5517924fc = $(`&lt;div id=&quot;html_0c08f955e59c885919f1f5a5517924fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WARRANTS&lt;/div&gt;`)[0];
#             popup_e47010b528de57876ce302e3877f55e3.setContent(html_0c08f955e59c885919f1f5a5517924fc);
#
#
#         circle_marker_b7cde353c5ac4f62bc0c32e97d84b07c.bindPopup(popup_e47010b528de57876ce302e3877f55e3)
#         ;
#
#
#
#
#             var circle_marker_feacf88e5672a1eb38174ced744abeb7 = L.circleMarker(
#                 [37.78578838, -122.4129705],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;pink&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;:

# %% [markdown]
# - Now, I want to apply another proper remedy to group the markers into different clusters. I will represent each cluster by the number of crimes in each neighborhood. These clusters can be thought of as pockets of San Francisco which can be analyzed separately.
#
# - I will do it by instantiating a MarkerCluster object and adding all the data points in the dataframe to this object.

# %%
from folium import plugins

# let's start again with a clean copy of the map of San Francisco
SanFrancisco_map = folium.Map(location = [latitude, longitude], zoom_start = 10)

# instantiate a mark cluster object for the incidents in the dataframe
incidents = plugins.MarkerCluster().add_to(SanFrancisco_map)

# loop through the dataframe and add each data point to the mark cluster
for lat, lng, label, in zip(df.Y, df.X, df.Category):
    folium.Marker(
        location=[lat, lng],
        icon=None,
        popup=label,
    ).add_to(incidents)

SanFrancisco_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5c361d9f7c9cd0576ecb0fb52dcc858b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5c361d9f7c9cd0576ecb0fb52dcc858b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5c361d9f7c9cd0576ecb0fb52dcc858b = L.map(
#                 &quot;map_5c361d9f7c9cd0576ecb0fb52dcc858b&quot;,
#                 {
#                     center: [37.77, -122.42],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fce5a002e40a29c84e96fdd337d620d0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5c361d9f7c9cd0576ecb0fb52dcc858b);
#
#
#             var marker_cluster_1d9be34df29c9b4e8fc20f1bf516da97 = L.markerClusterGroup(
#                 {}
#             );
#             map_5c361d9f7c9cd0576ecb0fb52dcc858b.addLayer(marker_cluster_1d9be34df29c9b4e8fc20f1bf516da97);
#
#
#             var marker_95060bdc8624fa104d3df52acffc98c0 = L.marker(
#                 [37.77542071, -122.4034048],
#                 {}
#             ).addTo(marker_cluster_1d9be34df29c9b4e8fc20f1bf516da97);
#
#
#         var popup_d8f6f48c5e1b59e7378a17abb99d05c6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_99b73e3b41725ea04288d38e7210df12 = $(`&lt;div id=&quot;html_99b73e3b41725ea04288d38e7210df12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;`)[0];
#             popup_d8f6f48c5e1b59e7378a17abb99d05c6.setContent(html_99b73e3b41725ea04288d38e7210df12);
#
#
#         marker_95060bdc8624fa104d3df52acffc98c0.bindPopup(popup_d8f6f48c5e1b59e7378a17abb99d05c6)
#         ;
#
#
#
#
#             var marker_b0762349491b7c0e7a7ccd6d5a101769 = L.marker(
#                 [37.77542071, -122.4034048],
#                 {}
#             ).addTo(marker_cluster_1d9be34df29c9b4e8fc20f1bf516da97);
#
#
#         var popup_f513d4b6bc801d8b5c32cfd4eb446987 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b62bd831472782501e4830f13b2da96d = $(`&lt;div id=&quot;html_b62bd831472782501e4830f13b2da96d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;`)[0];
#             popup_f513d4b6bc801d8b5c32cfd4eb446987.setContent(html_b62bd831472782501e4830f13b2da96d);
#
#
#         marker_b0762349491b7c0e7a7ccd6d5a101769.bindPopup(popup_f513d4b6bc801d8b5c32cfd4eb446987)
#         ;
#
#
#
#
#             var marker_6ee57cae9f0ffb29aa12f78bd13a9a18 = L.marker(
#                 [37.72998097, -122.3888562],
#                 {}
#             ).addTo(marker_cluster_1d9be34df29c9b4e8fc20f1bf516da97);
#
#
#         var popup_1c032cf1d21ca57b21518f7fd30f8768 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_30c8b96b389a2354557fca9d2bc3b4c3 = $(`&lt;div id=&quot;html_30c8b96b389a2354557fca9d2bc3b4c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WARRANTS&lt;/div&gt;`)[0];
#             popup_1c032cf1d21ca57b21518f7fd30f8768.setContent(html_30c8b96b389a2354557fca9d2bc3b4c3);
#
#
#         marker_6ee57cae9f0ffb29aa12f78bd13a9a18.bindPopup(popup_1c032cf1d21ca57b21518f7fd30f8768)
#         ;
#
#
#
#
#             var marker_c0cda4a86099ca0a7018926679c66baa = L.marker(
#                 [37.78578838, -122.4129705],
#                 {}
#             ).addTo(marker_cluster_1d9be34df29c9b4e8fc20f1bf516da97);
#
#
#         var popup_bcc965d1d4532c6aacc7996ce1524652 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a00134cf823c128a1d61e4a3ba057e56 = $(`&lt;div id=&quot;html_a00134cf823c128a1d61e4a3ba057e56&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NON-CRIMINAL&lt;/div&gt;`)[0];
#             popup_bcc965d1d4532c6aacc7996ce1524652.setContent(html_a00134cf823c128a1d61e4a3ba057e56);
#
#
#         marker_c0cda4a86099ca0a7018926679c66baa.bindPopup(popup_bcc965d1d4532c6aacc7996ce1524652)
#         ;
#
#
#
#
#             var marker_8d12c0b345f3d5076b78c2991724a915 = L.marker(
#                 [37.76505012, -122.4196718],
#                 {}
#             ).addTo(marker_cluster_1d9be34df29c9b4e8fc20f1bf516da97);
#
#
#         var popup_2295351665db927f15f3e2dd3e6d4d05 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b163911cef6f2932ffdd664965eb6b40 = $(`&lt;div id=&quot;html_b163911cef6f2932ffdd664965eb6b40&quot; styl
